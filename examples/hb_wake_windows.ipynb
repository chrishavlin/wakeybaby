# %%
import os
from wakeybaby.data_structures import Huckle
import pandas as pd 

file_dir = os.environ.get("WAKEYBABYDATADIR")
filename = os.path.join(file_dir, "hb_export.csv")

hb = Huckle(filename)

# %%
df = hb.wake_window()

# %%
import matplotlib.pyplot as plt 

plt.hist(df.time_awake.dt.total_seconds()/60, bins=100);

# %%
import numpy as np


plt.hist(df.time_awake.dt.total_seconds()/60, bins=np.linspace(0,180,50));
